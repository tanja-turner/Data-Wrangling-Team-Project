# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.arange(10)
plt.plot(data)

# %%
#subplot
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
plt.plot(np.random.randn(50).cumsum(), 'k--')
fig.add_subplot(2, 3, 4)
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True) 
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %%
#labels
fig = plt.figure(figsize=(6,3))
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %%
plt.figure(figsize=(6,4))
plt.scatter(pdf['Age'], pdf['Weight'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e7f506616fdb> in <module>
#       1 plt.figure(figsize=(6,4))
# ----> 2 plt.scatter(pdf['Age'], pdf['Weight'])
#
# NameError: name 'pdf' is not defined

# %%
 
plt.figure(figsize=(3,2))
plt.hist(heights,color='orange',edgecolor='k')
plt.title("Histogram of teen aged students's height",fontsize=18)
plt.xlabel("Height in cm",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-493098bd54ed> in <module>
#       1 plt.figure(figsize=(3,2))
# ----> 2 plt.hist(heights,color='orange',edgecolor='k')
#       3 plt.title("Histogram of teen aged students's height",fontsize=18)
#       4 plt.xlabel("Height in cm",fontsize=15)
#       5 plt.xticks(fontsize=15)
#
# NameError: name 'heights' is not defined

# %%
#save plot
plt.savefig('gpath.png', dpi=400, bbox_inches='tight')

# %%
#select from index
obj2[['c', 'a', 'd']]
#update value by index
obj2[['c', 'a', 'd']] = [3, -5, 6]
obj2
#filter 
obj2[obj2 > 0]
#null
obj4.isnull()
#select 
obj[2:4]
obj['b':'c']
#unique
obj.unique()
#count
obj.value_count()
#filter if its in 
mask = obj.isin(['b', 'c'])
obj[mask]

# %%
#dataframe
df=pd.read_csv('thanksgiving.csv',encoding='latin1')
#select multi column
pd.DataFrame(data, columns=['year', 'state', 'pop'])
#select rows by index
df2.loc['three']
df.iloc[2]
#new column
df2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],index=['one', 'two', 'three', 'four','five', 'six'])
df2['debt'] = np.arange(6.)
#new column w/ condition
df2['eastern'] = df2.state == 'Ohio'
#del col
del df2['eastern']
#drop index
obj.drop('c')
df.drop(['Colorado', 'Ohio'])
#drop colum
df.drop('two', axis=1)
df.drop(['two', 'four'], axis='columns')
obj.drop('c', inplace=True )
#update index
pd.DataFrame(pop, index=[2001, 2002, 2003])
#transpose
df3.T
#reindex
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
#select
df[df['three'] > 5]
df[df < 5] = 0
#col=Colorado, row='two','three'
df.loc['Colorado', ['two','three']]
df.loc[:'Utah', 'two']
#index=2, col=3, 0, 1
df.iloc[2, [3, 0, 1]]
df.iloc[:, :3][df.three >5] #: rows #:3 col

# %%
#array
import array as arr
a = arr.array('i', [1, 2, 3])
#creating
list_2 = [i for i in range(1,6)]
array_2 = np.array(list_2)
#shape di,
mat1.shape
mat1.dtype
#select
Elements at 2nd, 4th, and 9th index are: [ 4  8 18]
print("Elements at 2nd, 4th, and 9th index are:", arr[[2,4,9]])

print("3 Elements from last backwards are:", arr[-1:-6:-2])
#matric select
print("Matrix with row indices 1 and 2 and column indices 3 and 4\n" , mat[1:3,3:5])
print("Matrix with row indices 0 and 1 and column indices 1 and 3\n" , mat[0:2,[1,3]])
#stack
np.vstack((a,b))

# %%
plt.xlim([0,100])
# Out:
# (0.0, 100.0)

# %%
df=plt.figure(figsize=(3, 2))plot.scatter('Weight','Height', s=150, c='orange', edgecolor='k')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-9d5ae9abe4e2> in <module>
#       1 df=plt.figure(figsize=(3, 2))
# ----> 2 df.plot.scatter('Weight','Height', s=150, c='orange', edgecolor='k')
#
# AttributeError: 'Figure' object has no attribute 'plot'

# %%
plt.xlim()
# Out:
# (0.0, 1.0)

# %%
plt.plot(np.random.randn(30).cumsum(),color='green',linestyle='s')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-80c53ae90c10> in <module>
# ----> 1 plt.plot(np.random.randn(30).cumsum(),color='green',linestyle='s')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...
